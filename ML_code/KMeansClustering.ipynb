# %% [markdown]
# # K means clustering
# Importing the libraries

# %%
#Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
#import the dataset
df = pd.read_csv('/content/Iris[1].csv')
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# Plotting/visualizing the data

# %%
sns.scatterplot(x='Id', y='SepalLengthCm', hue='Species', data=df)
# Placing Legend outside the Figure
plt.legend(bbox_to_anchor=(1, 1), loc=2)
plt.show()

# %% [markdown]
# Applying K means clustering

# %%
x = df.iloc[:, [0,1,2,3]].values

kmeans = KMeans(n_clusters=7)
y_kmeans = kmeans.fit_predict(x)

print(kmeans.cluster_centers_)
# Out:
# [[ 33.5          4.96363636   3.33636364   1.45909091]
#  [117.5          6.55909091   2.92272727   5.53181818]
#  [ 75.5          6.035        2.76         4.365     ]
#  [ 55.           5.69047619   2.97619048   3.47142857]
#  [139.5          6.61363636   3.02272727   5.49545455]
#  [ 11.5          5.05454545   3.48636364   1.45      ]
#  [ 96.           6.0047619    2.83333333   4.61904762]]

# %% [markdown]
# the dataset in clusters

# %%
plt.scatter(x[:,0],x[:,1],c=y_kmeans,cmap='rainbow')
